# %%
from openmeteopy import OpenMeteo
from openmeteopy.hourly import HourlyForecast
from openmeteopy.daily import DailyForecast
from openmeteopy.options import ForecastOptions
from itertools import product
import pandas as pd
from folium.plugins import HeatMap
import folium
import os

# %% [markdown]
# # Data Query Prototyping

# %%
# Creating hourly forecast object
hourly = HourlyForecast()


latitude = 45.5152
longitude = -122.6784

# Defining variables we want to return
hourly = hourly.temperature_2m()
hourly = hourly.cloudcover()
hourly = hourly.windspeed_10m()

# Selecting options
options = ForecastOptions(latitude = latitude, 
                          longitude = longitude,
                          forecast_days=3)

# Pulling Data
client = OpenMeteo(options, hourly)

# Download data
meteo = client.get_pandas()
print(meteo)
# Out:
#                   temperature_2m  cloudcover  windspeed_10m
# time
# 2024-11-18T00:00             7.7         100           14.8
# 2024-11-18T01:00             7.4          99           13.2
# 2024-11-18T02:00             6.1          99            7.7
# 2024-11-18T03:00             5.9         100            9.4
# 2024-11-18T04:00             5.8          99           18.2
# ...                          ...         ...            ...
# 2024-11-24T19:00             8.7          57            5.9
# 2024-11-24T20:00            10.1          50           10.2
# 2024-11-24T21:00            10.9          44           12.8
# 2024-11-24T22:00            10.9          63           13.0
# 2024-11-24T23:00            10.4          81           12.0
#
# [168 rows x 3 columns]

# %%
def return_surrounding_weather(latitude, longitude, margin = 0.01):
    
    latitudes = [latitude, latitude + margin, latitude - margin]
    longitudes = [longitude, longitude + margin, longitude - margin]

    # all locations to query
    locations = list(product(latitudes, longitudes))
    output_data = []
    for location in locations:

        hourly = HourlyForecast()
        # Extracting latitude and longtitude for call
        lat_val = location[0]
        long_val = location[1]
        # Defining variables we want to return
        hourly = hourly.temperature_2m()
        hourly = hourly.cloudcover()
        hourly = hourly.windspeed_10m()

        # Selecting options
        options = ForecastOptions(latitude = lat_val, 
                                longitude = long_val,
                                forecast_days=3)

        # Pulling Data
        client = OpenMeteo(options, hourly)

        # Download data
        sample = client.get_pandas()
        sample['latitude'] = lat_val
        sample['longitude'] = long_val
        sample['location'] = str(location)
        #sample = sample.reset_index()
        output_data.append(sample)

    combined_weather_data = pd.concat(output_data)
    return combined_weather_data

# %%
latitude = 45.5152
longitude = -122.6784
combined_weather = return_surrounding_weather(latitude, longitude, margin = 0.02).reset_index()

# %%
combined_weather.to_csv('weather_data.csv')

# %% [markdown]
# # Geo Plot Prototyping

# %%
def plotPoint(row, map):

    '''Takes row in dataframe and folium map object and plots latitude/longitude
    point in dataframe onto map object'''

    folium.CircleMarker(location=[row.latitude, row.longitude],
                        radius=4,
                        weight=row.temperature_2m).add_to(map)

# %%
# Reading data
df1 = pd.read_csv("c://Users//seelc//OneDrive//Desktop//Lucas Desktop Items//Projects//forecasting//Data//weather_data.csv")

# Creating datafrom of last measurement from each location
number_of_locations = len(df1['location'].drop_duplicates())
df1 = df1.sort_values(by = 'time', ascending=True).reset_index(drop=True)
last_observation_df = df1.head(number_of_locations)
df1.head(10)
# Out:
#    Unnamed: 0              time  temperature_2m  cloudcover  windspeed_10m  \
# 0           0  2024-10-31T00:00             9.2          98           10.1
# 1         168  2024-10-31T00:00             9.4          98            7.6
# 2        1344  2024-10-31T00:00             7.5         100           14.0
# 3        1008  2024-10-31T00:00             8.9          98           10.1
# 4         336  2024-10-31T00:00             8.9         100            9.7
# 5         672  2024-10-31T00:00             9.2          98            7.4
# 6         840  2024-10-31T00:00             9.4         100            9.7
# 7        1176  2024-10-31T00:00             9.3          98            7.6
# 8         504  2024-10-31T00:00             9.5          98            7.4
# 9        1009  2024-10-31T01:00             7.8         100           11.7
#
#    latitude  longitude                        location
# 0   45.5152  -122.6784            (45.5152, -122.6784)
# 1   45.5152  -122.6584            (45.5152, -122.6584)
# 2   45.4952  -122.6984  (45.4952, -122.69839999999999)
# 3   45.4952  -122.6784            (45.4952, -122.6784)
# 4   45.5152  -122.6984  (45.5152, -122.69839999999999)
# 5   45.5352  -122.6584            (45.5352, -122.6584)
# 6   45.5352  -122.6984  (45.5352, -122.69839999999999)
# 7   45.4952  -122.6584            (45.4952, -122.6584)
# 8   45.5352  -122.6784            (45.5352, -122.6784)
# 9   45.4952  -122.6784            (45.4952, -122.6784)

# %%
portland_coordinates = [45.523, -122.676]
map = folium.Map(location= portland_coordinates, 
                 zoom_start=10, 
                 control_scale=True)

# Iterating through dataframe and plotting points
for index, row in last_observation_df.iterrows():
    plotPoint(row, map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4d22e419a1d7a1bb94e45e3a706996b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4d22e419a1d7a1bb94e45e3a706996b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4d22e419a1d7a1bb94e45e3a706996b = L.map(
#                 &quot;map_c4d22e419a1d7a1bb94e45e3a706996b&quot;,
#                 {
#                     center: [45.523, -122.676],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c4d22e419a1d7a1bb94e45e3a706996b);
#
#
#
#
#
#             var tile_layer_91ed2bb8d162bbdce925f5a0409dbe7e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_91ed2bb8d162bbdce925f5a0409dbe7e.addTo(map_c4d22e419a1d7a1bb94e45e3a706996b);
#
#
#             var circle_marker_26b55738e6fd3e98ea611b1e49c67c8e = L.circleMarker(
#                 [45.5152, -122.6784],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 9.2}
#             ).addTo(map_c4d22e419a1d7a1bb94e45e3a706996b);
#
#
#             var circle_marker_2ddad043b2a774ee031ba6fddf9da862 = L.circleMarker(
#                 [45.5152, -122.6584],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 9.4}
#             ).addTo(map_c4d22e419a1d7a1bb94e45e3a706996b);
#
#
#             var circle_marker_222737c74b103c3765093f2848c1b343 = L.circleMarker(
#                 [45.4952, -122.6984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 7.5}
#             ).addTo(map_c4d22e419a1d7a1bb94e45e3a706996b);
#
#
#             var circle_marker_5b7223e0bdd126a061e151cf2dbaca2c = L.circleMarker(
#                 [45.4952, -122.6784],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 8.9}
#             ).addTo(map_c4d22e419a1d7a1bb94e45e3a706996b);
#
#
#             var circle_marker_fd6d3a60f541b7e458bdde089398c11d = L.circleMarker(
#                 [45.5152, -122.6984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 8.9}
#             ).addTo(map_c4d22e419a1d7a1bb94e45e3a706996b);
#
#
#             var circle_marker_0fb3066844dee0db3f283635b74af863 = L.circleMarker(
#                 [45.5352, -122.6584],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 9.2}
#             ).addTo(map_c4d22e419a1d7a1bb94e45e3a706996b);
#
#
#             var circle_marker_35320dca518e7122e78e66c9

# %% [markdown]
# ### Creating Heatmap

# %%
# Creating base map
base_map = folium.Map(location=portland_coordinates,
                   control_scale=True, 
                   zoom_start=10)

# Extracting data
map_values1 = df1[['latitude', 'longitude', 'temperature_2m']]
data = map_values1.values.tolist()

# Creating heatmap
hm = HeatMap(data,gradient={0.1: 'blue', 0.3: 'lime', 0.5: 'yellow', 0.7: 'orange', 1: 'red'}, 
                min_opacity=0.05, 
                max_opacity=0.9, 
                radius=50,
                use_local_extrema=False)

# Adding to basemap
base_map.add_child(hm)

#m = folium.Map(data_for_heatmap.values,  tiles = 'stamentoner', zoom_start=10, control_scale=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_072bbaf72560f4e2e79ca9e711054158 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_072bbaf72560f4e2e79ca9e711054158&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_072bbaf72560f4e2e79ca9e711054158 = L.map(
#                 &quot;map_072bbaf72560f4e2e79ca9e711054158&quot;,
#                 {
#                     center: [45.523, -122.676],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_072bbaf72560f4e2e79ca9e711054158);
#
#
#
#
#
#             var tile_layer_c427574a8486cc71dab81f82cd2daad6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c427574a8486cc71dab81f82cd2daad6.addTo(map_072bbaf72560f4e2e79ca9e711054158);
#
#
#             var heat_map_cbb4c75c79071d4cd5872c81476fd33d = L.heatLayer(
#                 [[45.5152, -122.6784, 9.2], [45.5152, -122.6584, 9.4], [45.4952, -122.6984, 7.5], [45.4952, -122.6784, 8.9], [45.5152, -122.6984, 8.9], [45.5352, -122.6584, 9.2], [45.5352, -122.6984, 9.4], [45.4952, -122.6584, 9.3], [45.5352, -122.6784, 9.5], [45.4952, -122.6784, 7.8], [45.5352, -122.6584, 8.4], [45.5352, -122.6784, 8.7], [45.5152, -122.6584, 8.5], [45.5152, -122.6784, 8.2], [45.5152, -122.6984, 7.9], [45.4952, -122.6984, 6.5], [45.4952, -122.6584, 8.5], [45.5352, -122.6984, 8.4], [45.4952, -122.6784, 7.4], [45.5352, -122.6784, 7.9], [45.5152, -122.6584, 7.9], [45.5152, -122.6784, 7.7], [45.4952, -122.6984, 6.2], [45.5352, -122.6984, 7.8], [45.4952, -122.6584, 7.8], [45.5152, -122.6984, 7.3], [45.5352, -122.6584, 7.6], [45.5152, -122.6784, 7.4], [45.5152, -122.6984, 7.0], [45.5152, -122.6584, 7.7], [45.5352, -122.6784, 7.7], [45.5352, -122.6584, 7.5], [45.4952, -122.6784, 7.1], [45.5352, -122.6984, 7.5], [45.4952, -122.6584, 7.6], [45.4952, -122.6984, 5.8], [45.5352, -122.6984, 7.1], [45.4952, -122.6984, 5.7], [45.5152, -122.6584, 7.7], [45.5352, -122.6584, 7.3], [45.5352, -122.6784, 7.6], [45.5152, -122.6784, 7.5], [45.4952, -122.6784, 7.1], [45.5152, -122.6984, 6.7], [45.4952, -122.6584, 7.7], [45.4952, -122.6784, 7.4], [45.5352, -122.6984, 7.7], [45.5152, -122.6784, 7.7], [45.5152, -122.6984, 7.2], [45.5352, -122.6584, 7.6], [45.4952, -122.6584, 7.8], [45.5152, -122.6584, 7.8], [45.4952, -122.6984, 6.1], [45.5352, -122.6784, 7.9], [45.4952, -122.6784, 6.8], [45.5352, -122.6984, 7.1], [45.5152, -122.6784, 7.1], [45.4952, -122.6584, 7.2], [45.5152, -122.6984, 6.6], [45.5352, -122.6784, 7.4], [45.4952, -122.6984, 5.8], [45.5352, -122.6584, 7.2], [45.5152, -122.6584, 7.3], [45.4952, -122.6784, 6.5], [45.5152, -122.6784, 6.9], [45.5152, -122.6984, 6.5], [45.5352, -122.6784, 7.1], [45.5352, -122.6584, 6.9], [45.5352, -122.6984, 6.9], [45.4952, -122.6984, 5.3], [45.4952, -122.6584, 6.9], [45.5152, -122.6584, 7.0], [45.5152, -122.6984, 6.4], [45.4952, -122.6784, 6.3], [45.4952, -122.6584, 6.6], [45.5152, -122.6784, 6.7], [45.5352, -122.6984, 6.8], [45.5352, -122.6784, 6.9], [45.4952, -122.6984, 5.2], [45.5352, -122.6584, 6.6], [45.5152, -122.6584, 6.6], [45.5352, -122.6984, 6.9], [45.5152, -122.6984, 6.4], [45.5352, -122.6784, 7.0], [45.4952, -122.6584, 6.8], [45.4952, -122.6784, 6.4], [45.4952, -122.6984, 5.2], [45.5152, -122.6584, 6.8], [45.5352, -122.6584, 6.7], [45.5152, -122.6784, 6.8], [45.5352, -122.6584, 6.3], [45.5352, -122.6784, 6.5], [45.4952, -122.6784, 5.9], [45.5152, -122.6584, 6.3], [45.4952, -122.6984, 4.7], [45.5152, -122.6784, 6.3], [45.5152, -122.6984, 6.1], [45.4952, -122.6584, 6.2], [45.5352, -122.6984, 6.5], [45.5152, -122.6984, 6.1], [45.5352, -122.6984, 6.6], [45.5352, -122.6784, 6.8], [45.4952, -122.6584, 6.5], [45.5352, -122.6584, 6.5], [45.4952, -122.6784, 6.0], [45.5152, -122.6784, 6.3], [45.4952, -122.6984, 5.0], [45.5152, -122.6584, 6.5], [45.5152, -122.6784, 6.2], [45.4952, -122.6784, 5.8], [45.4952, -122.6584, 5.9], [45.5352, -122.6784, 6.3], [45.5352, -122.6584, 6.0], [45.5152, -122.6984, 5.9], [45.4952, -122.6984, 4.8], [45.5352, -122.6984, 6.4], [45.5152, -122.6584, 5.9], [45.5352, -122.6784, 6.0], [45.5352, -122.6584, 5.7], [45.5352, -122.6984, 6.3], [45.4952, -122.6584, 5.8], [45.4952, -122.6984, 4.7], [45.5152, -122.6784, 6.1], [45.5152, -122.6984, 5.9], [45.4952, -122.6784, 5.8], [45.5152, -122.6584, 5.9], [45.5352, -122.6584, 5.7], [45.4952, -122.6784, 5.5], [45.5352, -122.6784, 5.9], [45.4952, -122.6984, 4.9], [45.4952, -122.6584, 5.5], [45.5152, -122.6784, 5.9], [45.5152, -122.6984, 5.7], [45.5352, -122.6984, 6.2], [45.5152, -122.6584, 5.6], [45.5152, -122.6584, 6.0], [45.5352, -122.6584, 6.0], [45.4952, -122.6784, 5.8], [45.4952, -122.6584, 6.0], [45.5152, -122.6784, 6.1], [45.5152, -122.6984, 5.8], [45.4952, -122.6984, 4.6], [4

# %% [markdown]
# ### Creating Heatmap with Time Dimension

# %%
m = folium.Map([48.0, 5.0], zoom_start=10)

# Creating time index's
time_index = df1['time'].drop_duplicates().to_list()

hm = folium.plugins.HeatMapWithTime(data, index=time_index, auto_play=True, max_opacity=0.3)

hm.add_to(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 6
#       3 # Creating time index's
#       4 time_index = df1['time'].drop_duplicates().to_list()
# ----> 6 hm = folium.plugins.HeatMapWithTime(data, index=time_index, auto_play=True, max_opacity=0.3)
#       8 hm.add_to(m)
#
# File c:\Users\seelc\OneDrive\Desktop\Lucas Desktop Items\Projects\forecasting\.venv\Lib\site-packages\folium\plugins\heat_map_withtime.py:169, in HeatMapWithTime.__init__(self, data, index, name, radius, blur, min_opacity, max_opacity, scale_radius, gradient, use_local_extrema, auto_play, display_index, index_steps, min_speed, max_speed, speed_step, position, overlay, control, show)
#     165 self.index = (
#     166     index if index is not None else [str(i) for i in range(1, len(data) + 1)]
#     167 )
#     168 if len(self.data) != len(self.index):
# --> 169     raise ValueError(
#     170         "Input data and index are not of compatible lengths."
#     171     )  # noqa
#     172 self.times = list(range(1, len(data) + 1))
#     174 # Heatmap settings.
#
# ValueError: Input data and index are not of compatible lengths.

# %%
import datetime
from dateutil import tz
from suntime import Sun, SunTimeException

# Replace with your desired coordinates
latitude = 37.7749
longitude = -122.4194

sun = Sun(latitude, longitude)

# Get today's sunrise and sunset in UTC
today_sr = sun.get_sunrise_time()
today_ss = sun.get_sunset_time()
print(type(today_sr))
print("Today's sunrise:", today_sr.strftime("%H:%M"))
print("Today's sunset:", today_ss.strftime("%H:%M"))

print((today_sr -  today_ss).days)
# Out:
# <class 'datetime.datetime'>
# Today's sunrise: 14:54
# Today's sunset: 00:55
# 0
